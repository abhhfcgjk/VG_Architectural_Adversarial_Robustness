# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import pandas as pd
import numpy as np

# %%
cols = ["arch", "activation", "attack", "iterations", "eps 2", "eps 4", "eps 6", "eps 8", "eps 10", "SROCC"]
data = pd.read_csv("rs/results.csv", header=0, usecols=cols)

# %%
data.sample(5, random_state=0)
# Out:
#                          arch activation attack  iterations     eps 2  \
# 45         resnet50-Linearity       Felu  IFGSM         5.0  0.213586
# 28         resnet50-Linearity      Fgelu  IFGSM         3.0  1.926825
# 29         resnet50-Linearity       Felu  IFGSM         3.0  0.175963
# 55         resnet50-Linearity  relu_gelu  IFGSM         1.0  0.337678
# 63  textureresnet50-Linearity       relu  IFGSM         5.0  1.634478
#
#        eps 4     eps 6     eps 8    eps 10     SROCC
# 45  0.216705  0.203963  0.196842  0.199499  0.836820
# 28  2.790682  3.114301  3.102121  2.987046  0.830303
# 29  0.196269  0.195506  0.182794  0.167262  0.836820
# 55  0.316484  0.270371  0.221533  0.172357  0.899888
# 63  1.750998  1.596155  1.370919  1.177739  0.904118

# %%
fsilu_data = data[(data["arch"]=="resnet50-Linearity")&(data["activation"]=="Fsilu")].loc[:,"eps 2": "eps 10"].values
print(fsilu_data[0][0],fsilu_data[-1])
# Out:
# 0.1636104025424969 [0.97357313 1.26601247 1.30603955 1.22152177 1.11837141]

# %%
group1 = [("resnet18-Linearity", "relu"), ("resnet34-Linearity", "relu"), ("resnet50-Linearity", "relu"), ("wideresnet50-Linearity", "relu")]
group2 = [("resnet50-Linearity", "relu"), ("resnet50-Linearity", "silu"), ("resnet50-Linearity", "relu_silu"),("resnet50-Linearity", "Fsilu"),("resnet50-Linearity", "elu"),("resnet50-Linearity", "gelu"),("resnet50-Linearity", "Fgelu"),("resnet50-Linearity", "Felu") ]
group3 = [("advresnet50-Linearity","relu"),("wideresnet50-Linearity", "relu"),("vonenet50-Linearity", "relu"),("resnet50-Linearity+prune=0.1pls", "relu"),("resnet50-Linearity+prune=0.1l1", "relu"),("resnet50-Linearity+prune=0.1l2", "relu")]
group4 = [("textureresnet50-Linearity","relu"), ("shaperesnet50-Linearity","relu"), ("debiasedresnet50-Linearity","relu")]

# %%
group = group2 + group3
groups = [group1, group2, group3+group4, group]
epsilons = [2, 4, 6, 8, 10]
eps_labels = ['','2/255','','4/255','','6/255','','8/255','','10/255']

fig, axs = plt.subplots(2,2, figsize=(16,10), subplot_kw={"xticks": list(range(1,11)),"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})
baseline = [('resnet18-Lineatiyt','relu'),('resnet50-Linearity','relu')]
axs[0,0].set_title("Base architecture")
axs[0,1].set_title("Activation function")
axs[1,0].set_title("Special architectures")
axs[1,1].set_title("All")
fig.tight_layout()

# axs[0,1].set_ylim(fsilu_data[0][1], fsilu_data[0][-1])

for i in range(4):
    axis = axs[i//2, i%2]
    grp = groups[i]
    for arch, activ in grp:
        y_axis = data[(data["arch"]==arch)&(data["iterations"]==1.0)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
        if (i==0 and (arch, activ) == baseline[0])or(i>0 and (arch, activ) == baseline[1]):
            axis.plot(epsilons, y_axis,'k--', marker=".",label=f"{arch} {activ}")
        else:
            axis.plot(epsilons, y_axis, marker=".",label=f"{arch} {activ}")
    axis.legend(loc="upper right")

plt.show()
fig.savefig('graph4.png')

# %%
x = [2, 4, 6, 8, 10]
grp = set(group1+group2+group3+group4)
df1 = pd.DataFrame(columns=['architecture', 'activation', 'SROCC','result'])
for arch, activ in grp:
    y_axis = data[(data["arch"]==arch)&(data["iterations"]==1.0)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
    srocc = data[(data["arch"]==arch)&(data["iterations"]==1.0)&(data["activation"]==activ)].loc[:,"SROCC"].values.tolist()[0]
    df1.loc[len(df1)] = {'architecture': arch, 
                       'activation': activ,
                       'SROCC': format(srocc,'.2f'),
                       'result': format(np.trapz(y_axis, x), '.2f')}
df1.sort_values('result').style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_8bffa">
#   <thead>
#     <tr>
#       <th id="T_8bffa_level0_col0" class="col_heading level0 col0" >architecture</th>
#       <th id="T_8bffa_level0_col1" class="col_heading level0 col1" >activation</th>
#       <th id="T_8bffa_level0_col2" class="col_heading level0 col2" >SROCC</th>
#       <th id="T_8bffa_level0_col3" class="col_heading level0 col3" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8bffa_row0_col0" class="data row0 col0" >debiasedresnet50-Linearity</td>
#       <td id="T_8bffa_row0_col1" class="data row0 col1" >relu</td>
#       <td id="T_8bffa_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_8bffa_row0_col3" class="data row0 col3" >0.72</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row1_col0" class="data row1 col0" >advresnet50-Linearity</td>
#       <td id="T_8bffa_row1_col1" class="data row1 col1" >relu</td>
#       <td id="T_8bffa_row1_col2" class="data row1 col2" >0.85</td>
#       <td id="T_8bffa_row1_col3" class="data row1 col3" >0.88</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row2_col0" class="data row2 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row2_col1" class="data row2 col1" >Felu</td>
#       <td id="T_8bffa_row2_col2" class="data row2 col2" >0.84</td>
#       <td id="T_8bffa_row2_col3" class="data row2 col3" >0.88</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row3_col0" class="data row3 col0" >resnet50-Linearity+prune=0.1pls</td>
#       <td id="T_8bffa_row3_col1" class="data row3 col1" >relu</td>
#       <td id="T_8bffa_row3_col2" class="data row3 col2" >0.91</td>
#       <td id="T_8bffa_row3_col3" class="data row3 col3" >0.95</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row4_col0" class="data row4 col0" >resnet50-Linearity+prune=0.1l2</td>
#       <td id="T_8bffa_row4_col1" class="data row4 col1" >relu</td>
#       <td id="T_8bffa_row4_col2" class="data row4 col2" >0.91</td>
#       <td id="T_8bffa_row4_col3" class="data row4 col3" >1.03</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row5_col0" class="data row5 col0" >resnet50-Linearity+prune=0.1l1</td>
#       <td id="T_8bffa_row5_col1" class="data row5 col1" >relu</td>
#       <td id="T_8bffa_row5_col2" class="data row5 col2" >0.91</td>
#       <td id="T_8bffa_row5_col3" class="data row5 col3" >1.07</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row6_col0" class="data row6 col0" >shaperesnet50-Linearity</td>
#       <td id="T_8bffa_row6_col1" class="data row6 col1" >relu</td>
#       <td id="T_8bffa_row6_col2" class="data row6 col2" >0.90</td>
#       <td id="T_8bffa_row6_col3" class="data row6 col3" >1.18</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row7_col0" class="data row7 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row7_col1" class="data row7 col1" >elu</td>
#       <td id="T_8bffa_row7_col2" class="data row7 col2" >0.91</td>
#       <td id="T_8bffa_row7_col3" class="data row7 col3" >1.34</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row8_col0" class="data row8 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row8_col1" class="data row8 col1" >relu_silu</td>
#       <td id="T_8bffa_row8_col2" class="data row8 col2" >0.91</td>
#       <td id="T_8bffa_row8_col3" class="data row8 col3" >1.44</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row9_col0" class="data row9 col0" >resnet34-Linearity</td>
#       <td id="T_8bffa_row9_col1" class="data row9 col1" >relu</td>
#       <td id="T_8bffa_row9_col2" class="data row9 col2" >0.90</td>
#       <td id="T_8bffa_row9_col3" class="data row9 col3" >1.46</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row10_col0" class="data row10 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row10_col1" class="data row10 col1" >silu</td>
#       <td id="T_8bffa_row10_col2" class="data row10 col2" >0.90</td>
#       <td id="T_8bffa_row10_col3" class="data row10 col3" >1.49</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row11_col0" class="data row11 col0" >textureresnet50-Linearity</td>
#       <td id="T_8bffa_row11_col1" class="data row11 col1" >relu</td>
#       <td id="T_8bffa_row11_col2" class="data row11 col2" >0.90</td>
#       <td id="T_8bffa_row11_col3" class="data row11 col3" >1.59</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row12_col0" class="data row12 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row12_col1" class="data row12 col1" >relu</td>
#       <td id="T_8bffa_row12_col2" class="data row12 col2" >0.91</td>
#       <td id="T_8bffa_row12_col3" class="data row12 col3" >1.61</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row13_col0" class="data row13 col0" >vonenet50-Linearity</td>
#       <td id="T_8bffa_row13_col1" class="data row13 col1" >relu</td>
#       <td id="T_8bffa_row13_col2" class="data row13 col2" >0.86</td>
#       <td id="T_8bffa_row13_col3" class="data row13 col3" >1.75</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row14_col0" class="data row14 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row14_col1" class="data row14 col1" >Fsilu</td>
#       <td id="T_8bffa_row14_col2" class="data row14 col2" >0.81</td>
#       <td id="T_8bffa_row14_col3" class="data row14 col3" >1.96</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row15_col0" class="data row15 col0" >resnet18-Linearity</td>
#       <td id="T_8bffa_row15_col1" class="data row15 col1" >relu</td>
#       <td id="T_8bffa_row15_col2" class="data row15 col2" >0.90</td>
#       <td id="T_8bffa_row15_col3" class="data row15 col3" >2.04</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row16_col0" class="data row16 col0" >wideresnet50-Linearity</td>
#       <td id="T_8bffa_row16_col1" class="data row16 col1" >relu</td>
#       <td id="T_8bffa_row16_col2" class="data row16 col2" >0.91</td>
#       <td id="T_8bffa_row16_col3" class="data row16 col3" >2.42</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row17_col0" class="data row17 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row17_col1" class="data row17 col1" >gelu</td>
#       <td id="T_8bffa_row17_col2" class="data row17 col2" >0.91</td>
#       <td id="T_8bffa_row17_col3" class="data row17 col3" >2.69</td>
#     </tr>
#     <tr>
#       <td id="T_8bffa_row18_col0" class="data row18 col0" >resnet50-Linearity</td>
#       <td id="T_8bffa_row18_col1" class="data row18 col1" >Fgelu</td>
#       <td id="T_8bffa_row18_col2" class="data row18 col2" >0.83</td>
#       <td id="T_8bffa_row18_col3" class="data row18 col3" >6.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
group = group2 + group3
groups = [group1, group2, group3+group4, group]
epsilons = [2, 4, 6, 8, 10]
eps_labels = ['','2/255','','4/255','','6/255','','8/255','','10/255']

fig, axs = plt.subplots(2,2, figsize=(16,10), subplot_kw={"xticks": list(range(1,11)),"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})
baseline = [('resnet18-Lineatiyt','relu'),('resnet50-Linearity','relu')]
axs[0,0].set_title("Base architecture")
axs[0,1].set_title("Activation function")
axs[1,0].set_title("Special architectures")
axs[1,1].set_title("All")
fig.tight_layout()

# axs[0,1].set_ylim(fsilu_data[0][1], fsilu_data[0][-1])

for i in range(4):
    axis = axs[i//2, i%2]
    grp = groups[i]
    for arch, activ in grp:
        y_axis = data[(data["arch"]==arch)&(data["iterations"]==3.0)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
        if (i==0 and (arch, activ) == baseline[0])or(i>0 and (arch, activ) == baseline[1]):
            axis.plot(epsilons, y_axis,'k--', marker=".",label=f"{arch} {activ}")
        else:
            axis.plot(epsilons, y_axis, marker=".",label=f"{arch} {activ}")
    axis.legend(loc="upper right")

plt.show()
fig.savefig('graph4.png')

# %%
x = [2, 4, 6, 8, 10]
grp = set(group1+group2+group3+group4)
df2 = pd.DataFrame(columns=['architecture', 'activation', 'SROCC','result'])
for arch, activ in grp:
    y_axis = data[(data["arch"]==arch)&(data["iterations"]==3.0)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
    srocc = data[(data["arch"]==arch)&(data["iterations"]==3.0)&(data["activation"]==activ)].loc[:,"SROCC"].values.tolist()[0]
    df2.loc[len(df2)] = {'architecture': arch, 
                       'activation': activ,
                       'SROCC': format(srocc,'.2f'),
                       'result': float(format(np.trapz(y_axis, x), '.2f'))}
df2.sort_values(('result'))
# Out:
#                        architecture activation SROCC  result
# 11               resnet50-Linearity       Felu  0.84    1.49
# 9             advresnet50-Linearity       relu  0.85    2.90
# 5        debiasedresnet50-Linearity       relu  0.90    3.48
# 12               resnet34-Linearity       relu  0.90    3.95
# 16               resnet50-Linearity        elu  0.91    4.26
# 3   resnet50-Linearity+prune=0.1pls       relu  0.91    4.37
# 18   resnet50-Linearity+prune=0.1l1       relu  0.91    4.57
# 0                resnet50-Linearity       relu  0.91    4.77
# 7    resnet50-Linearity+prune=0.1l2       relu  0.91    4.83
# 14               resnet50-Linearity  relu_silu  0.91    5.90
# 4                resnet50-Linearity       silu  0.90    6.16
# 15              vonenet50-Linearity       relu  0.86    6.37
# 10          shaperesnet50-Linearity       relu  0.90    6.59
# 8                resnet50-Linearity      Fsilu  0.81    7.16
# 13               resnet18-Linearity       relu  0.90    7.38
# 17        textureresnet50-Linearity       relu  0.90    8.10
# 1                resnet50-Linearity       gelu  0.91   11.72
# 6            wideresnet50-Linearity       relu  0.91   13.25
# 2                resnet50-Linearity      Fgelu  0.83   22.93

# %%
group = group2 + group3
groups = [group1, group2, group3+group4, group]
epsilons = [2, 4, 6, 8, 10]
eps_labels = ['','2/255','','4/255','','6/255','','8/255','','10/255']

fig, axs = plt.subplots(2,2, figsize=(16,10), subplot_kw={"xticks": list(range(1,11)),"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})
baseline = [('resnet18-Lineatiyt','relu'),('resnet50-Linearity','relu')]
axs[0,0].set_title("Base architecture")
axs[0,1].set_title("Activation function")
axs[1,0].set_title("Special architectures")
axs[1,1].set_title("All")
fig.tight_layout()

# axs[0,1].set_ylim(fsilu_data[0][1], fsilu_data[0][-1])

for i in range(4):
    axis = axs[i//2, i%2]
    grp = groups[i]
    for arch, activ in grp:
        y_axis = data[(data["arch"]==arch)&(data["iterations"]==5.0)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
        if (i==0 and (arch, activ) == baseline[0])or(i>0 and (arch, activ) == baseline[1]):
            axis.plot(epsilons, y_axis,'k--', marker=".",label=f"{arch} {activ}")
        else:
            axis.plot(epsilons, y_axis, marker=".",label=f"{arch} {activ}")
    axis.legend(loc="upper right")

plt.show()
fig.savefig('graph4.png')

# %%
x = [2, 4, 6, 8, 10]
grp = set(group1+group2+group3+group4)
df = pd.DataFrame(columns=['architecture', 'activation', 'SROCC','result'])
for arch, activ in grp:
    y_axis = data[(data["arch"]==arch)&(data["iterations"]==5.0)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
    srocc = data[(data["arch"]==arch)&(data["iterations"]==5.0)&(data["activation"]==activ)].loc[:,"SROCC"].values.tolist()[0]
    df.loc[len(df)] = {'architecture': arch, 
                       'activation': activ,
                       'SROCC': format(srocc,'.2f'),
                       'result': format(np.trapz(y_axis, x), '.2f')}
df.sort_values('result').style.hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_2caa9">
#   <thead>
#     <tr>
#       <th id="T_2caa9_level0_col0" class="col_heading level0 col0" >architecture</th>
#       <th id="T_2caa9_level0_col1" class="col_heading level0 col1" >activation</th>
#       <th id="T_2caa9_level0_col2" class="col_heading level0 col2" >SROCC</th>
#       <th id="T_2caa9_level0_col3" class="col_heading level0 col3" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2caa9_row0_col0" class="data row0 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row0_col1" class="data row0 col1" >Felu</td>
#       <td id="T_2caa9_row0_col2" class="data row0 col2" >0.84</td>
#       <td id="T_2caa9_row0_col3" class="data row0 col3" >1.65</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row1_col0" class="data row1 col0" >resnet18-Linearity</td>
#       <td id="T_2caa9_row1_col1" class="data row1 col1" >relu</td>
#       <td id="T_2caa9_row1_col2" class="data row1 col2" >0.90</td>
#       <td id="T_2caa9_row1_col3" class="data row1 col3" >10.25</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row2_col0" class="data row2 col0" >shaperesnet50-Linearity</td>
#       <td id="T_2caa9_row2_col1" class="data row2 col1" >relu</td>
#       <td id="T_2caa9_row2_col2" class="data row2 col2" >0.90</td>
#       <td id="T_2caa9_row2_col3" class="data row2 col3" >10.76</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row3_col0" class="data row3 col0" >textureresnet50-Linearity</td>
#       <td id="T_2caa9_row3_col1" class="data row3 col1" >relu</td>
#       <td id="T_2caa9_row3_col2" class="data row3 col2" >0.90</td>
#       <td id="T_2caa9_row3_col3" class="data row3 col3" >12.25</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row4_col0" class="data row4 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row4_col1" class="data row4 col1" >gelu</td>
#       <td id="T_2caa9_row4_col2" class="data row4 col2" >0.91</td>
#       <td id="T_2caa9_row4_col3" class="data row4 col3" >16.88</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row5_col0" class="data row5 col0" >wideresnet50-Linearity</td>
#       <td id="T_2caa9_row5_col1" class="data row5 col1" >relu</td>
#       <td id="T_2caa9_row5_col2" class="data row5 col2" >0.91</td>
#       <td id="T_2caa9_row5_col3" class="data row5 col3" >20.30</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row6_col0" class="data row6 col0" >advresnet50-Linearity</td>
#       <td id="T_2caa9_row6_col1" class="data row6 col1" >relu</td>
#       <td id="T_2caa9_row6_col2" class="data row6 col2" >0.85</td>
#       <td id="T_2caa9_row6_col3" class="data row6 col3" >3.94</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row7_col0" class="data row7 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row7_col1" class="data row7 col1" >Fgelu</td>
#       <td id="T_2caa9_row7_col2" class="data row7 col2" >0.83</td>
#       <td id="T_2caa9_row7_col3" class="data row7 col3" >32.48</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row8_col0" class="data row8 col0" >resnet34-Linearity</td>
#       <td id="T_2caa9_row8_col1" class="data row8 col1" >relu</td>
#       <td id="T_2caa9_row8_col2" class="data row8 col2" >0.90</td>
#       <td id="T_2caa9_row8_col3" class="data row8 col3" >4.71</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row9_col0" class="data row9 col0" >debiasedresnet50-Linearity</td>
#       <td id="T_2caa9_row9_col1" class="data row9 col1" >relu</td>
#       <td id="T_2caa9_row9_col2" class="data row9 col2" >0.90</td>
#       <td id="T_2caa9_row9_col3" class="data row9 col3" >5.27</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row10_col0" class="data row10 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row10_col1" class="data row10 col1" >elu</td>
#       <td id="T_2caa9_row10_col2" class="data row10 col2" >0.91</td>
#       <td id="T_2caa9_row10_col3" class="data row10 col3" >5.63</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row11_col0" class="data row11 col0" >resnet50-Linearity+prune=0.1pls</td>
#       <td id="T_2caa9_row11_col1" class="data row11 col1" >relu</td>
#       <td id="T_2caa9_row11_col2" class="data row11 col2" >0.91</td>
#       <td id="T_2caa9_row11_col3" class="data row11 col3" >6.17</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row12_col0" class="data row12 col0" >resnet50-Linearity+prune=0.1l1</td>
#       <td id="T_2caa9_row12_col1" class="data row12 col1" >relu</td>
#       <td id="T_2caa9_row12_col2" class="data row12 col2" >0.91</td>
#       <td id="T_2caa9_row12_col3" class="data row12 col3" >6.35</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row13_col0" class="data row13 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row13_col1" class="data row13 col1" >relu</td>
#       <td id="T_2caa9_row13_col2" class="data row13 col2" >0.91</td>
#       <td id="T_2caa9_row13_col3" class="data row13 col3" >6.66</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row14_col0" class="data row14 col0" >resnet50-Linearity+prune=0.1l2</td>
#       <td id="T_2caa9_row14_col1" class="data row14 col1" >relu</td>
#       <td id="T_2caa9_row14_col2" class="data row14 col2" >0.91</td>
#       <td id="T_2caa9_row14_col3" class="data row14 col3" >6.80</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row15_col0" class="data row15 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row15_col1" class="data row15 col1" >relu_silu</td>
#       <td id="T_2caa9_row15_col2" class="data row15 col2" >0.91</td>
#       <td id="T_2caa9_row15_col3" class="data row15 col3" >8.29</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row16_col0" class="data row16 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row16_col1" class="data row16 col1" >silu</td>
#       <td id="T_2caa9_row16_col2" class="data row16 col2" >0.90</td>
#       <td id="T_2caa9_row16_col3" class="data row16 col3" >8.52</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row17_col0" class="data row17 col0" >vonenet50-Linearity</td>
#       <td id="T_2caa9_row17_col1" class="data row17 col1" >relu</td>
#       <td id="T_2caa9_row17_col2" class="data row17 col2" >0.86</td>
#       <td id="T_2caa9_row17_col3" class="data row17 col3" >9.53</td>
#     </tr>
#     <tr>
#       <td id="T_2caa9_row18_col0" class="data row18 col0" >resnet50-Linearity</td>
#       <td id="T_2caa9_row18_col1" class="data row18 col1" >Fsilu</td>
#       <td id="T_2caa9_row18_col2" class="data row18 col2" >0.81</td>
#       <td id="T_2caa9_row18_col3" class="data row18 col3" >9.68</td>
#     </tr>
#   </tbody>
# </table>

# %%
from PIL import Image
from torchvision.transforms.functional import resize
im10 = Image.open('./NIPS_test/4a0bac33f8e81e60.png').convert('RGB')

# im1 = resize(im, (96, 128))
im10
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
im20 = Image.open('./NIPS_test/7506caf0a49c3951.png').convert('RGB')
im20
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
from torchvision.transforms.functional import to_tensor, normalize
import torchvision.transforms as T
import numpy as np

alpha = 0.8

im1_, im2_ = to_tensor(im10), to_tensor(im20)
im1,im2 = normalize(im1_, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),normalize(im2_, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) 
index = [2,1,0]

# %%
# im = normalize(im, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
lam = np.random.beta(alpha, alpha)
im = (1-lam)*im1 + lam*im2
transform = T.ToPILImage()
transform(im)
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
lam
# Out:
# 0.8299276617650029

# %%
im = (1-lam)*im1
transform = T.ToPILImage()
transform(im)
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
im = (lam)*im2
transform = T.ToPILImage()
transform(im)
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>
