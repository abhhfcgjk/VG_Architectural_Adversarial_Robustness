# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
cols = ["arch", "activation", "attack", "iterations", "eps 2", "eps 4", "eps 6", "eps 8", "eps 10", "SROCC"]
data = pd.read_csv("rs/results.csv", header=0, usecols=cols)

# %%
data.sample(5, random_state=0)
# Out:
#                   arch activation attack  iterations     eps 2     eps 4  \
# 1             resnet18       silu  IFGSM           1  0.039062  0.058201
# 6         wideresnet50       relu  IFGSM           1  0.022592  0.031409
# 8             resnet50      Fsilu  IFGSM           1  0.040113  0.066709
# 10            resnet18      Fsilu  IFGSM           1  0.028127  0.051919
# 14  resnet34+prune=0.2       relu    PGD           5  0.101988  0.154486
#
#        eps 6     eps 8    eps 10     SROCC
# 1   0.068903  0.075893  0.081801  0.892089
# 6   0.035890  0.037915  0.038926  0.914137
# 8   0.091725  0.117780  0.145800  0.805964
# 10  0.073056  0.093081  0.112755  0.857626
# 14  0.167064  0.150960  0.140199  0.902069

# %%
data[(data["arch"]=="resnet50")&(data["activation"]=="Fsilu")].loc[:,"eps 2": "eps 10"].values
# Out:
# array([[0.04011309, 0.06670947, 0.09172539, 0.11778046, 0.14579967]])

# %%
group1 = [("resnet18", "relu"), ("resnet34", "relu"), ("resnet50", "relu"), ("wideresnet50", "relu")]
group2 = [("resnet50", "relu"), ("resnet50", "silu"), ("resnet50", "Fsilu")]
group3 = [("wideresnet50", "relu"),("vonenet50", "relu")]

# %%
group = group2 + group3
groups = [group1, group2, group3, group]
epsilons = [2, 4, 6, 8, 10]
eps_labels = ['','2/255','','4/255','','6/255','','8/255','','10/255']

fig, axs = plt.subplots(2,2, figsize=(16,8), subplot_kw={"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})

for i in range(4):
    axis = axs[i//2, i%2]
    grp = groups[i]
    for arch, activ in grp:
        y_axis = data[(data["arch"]==arch)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
        axis.plot(epsilons, y_axis, marker=".",label=f"{arch} {activ}")
    axis.legend(loc="upper left")

plt.show()
# Out:
# /tmp/ipykernel_13247/1874267539.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig, axs = plt.subplots(2,2, figsize=(16,8), subplot_kw={"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})
# /tmp/ipykernel_13247/1874267539.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig, axs = plt.subplots(2,2, figsize=(16,8), subplot_kw={"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})
# /tmp/ipykernel_13247/1874267539.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig, axs = plt.subplots(2,2, figsize=(16,8), subplot_kw={"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})
# /tmp/ipykernel_13247/1874267539.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   fig, axs = plt.subplots(2,2, figsize=(16,8), subplot_kw={"xticklabels": eps_labels, "xlabel": "Epsilon", "ylabel": "Gain"})

# %%
x = [2, 4, 6, 8, 10]
grp = set(group1+group2+group3)
df = pd.DataFrame(columns=['architecture', 'activation', 'result'])
for arch, activ in grp:
    y_axis = data[(data["arch"]==arch)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
    
    df.loc[len(df)] = {'architecture': arch, 'activation': activ, 'result': np.trapz(y_axis, x)}
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 7
#       4 for arch, activ in grp:
#       5     y_axis = data[(data["arch"]==arch)&(data["activation"]==activ)].loc[:,f"eps {epsilons[0]}": f"eps {epsilons[-1]}"].values.tolist()[0]
# ----> 7     df.iloc[len(df)] = {'architecture': arch, 'activation': activ, 'result': np.trapz(y_axis, x)}
#       8 df
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:908, in _LocationIndexer.__setitem__(self, key, value)
#     906     key = self._check_deprecated_callable_usage(key, maybe_callable)
#     907 indexer = self._get_setitem_indexer(key)
# --> 908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
#     911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/anaconda3/envs/ml/lib/python3.12/site-packages/pandas/core/indexing.py:1646, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1644 elif is_integer(i):
#    1645     if i >= len(ax):
# -> 1646         raise IndexError("iloc cannot enlarge its target object")
#    1647 elif isinstance(i, dict):
#    1648     raise IndexError("iloc cannot enlarge its target object")
#
# IndexError: iloc cannot enlarge its target object
